# %%
import json
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
with open('../data/em1/all.json') as data_file:    
    em1 = json.load(data_file)
with open('../data/sl1/all.json') as data_file:    
    sl1 = json.load(data_file)
with open('../data/si1/all.json') as data_file:    
    si1 = json.load(data_file)
with open('../data/st1/all.json') as data_file:    
    st1 = json.load(data_file)
    
with open('../data/em2/all.json') as data_file:    
    em2 = json.load(data_file)
with open('../data/sl2/all.json') as data_file:    
    sl2 = json.load(data_file)
with open('../data/si2/all.json') as data_file:    
    si2 = json.load(data_file)
with open('../data/st2/all.json') as data_file:    
    st2 = json.load(data_file)
    
with open('../data/em3/all.json') as data_file:    
    em3 = json.load(data_file)
with open('../data/sl3/all.json') as data_file:    
    sl3 = json.load(data_file)
with open('../data/si3/all.json') as data_file:    
    si3 = json.load(data_file)
with open('../data/st3/all.json') as data_file:    
    st3 = json.load(data_file)

# %%
data = np.concatenate((em1, sl1, si1, st1, em2, sl2, si2, st2, em3, sl3, si3, st3), axis=0)

# %%
np.set_printoptions(threshold=np.nan)
np.set_printoptions(precision=2,suppress=True)
print (data)
# Out:
# [[ -13.94   -4.78  -14.3   -18.99  -22.57  -17.87  -15.2   -11.62   -6.93
#     -4.     -5.19   -2.88    0.     10.      9.      0.  ]
#  [ -16.41   -4.58  -12.06  -15.64  -18.65  -15.08  -11.28   -8.27   -4.69
#     -3.44   -5.19   -2.88    0.     10.      9.      0.  ]
#  [ -16.41   -6.48  -17.22  -24.59  -32.74  -26.19  -22.15  -15.62   -8.25
#     -1.51   -5.35   -0.67    0.     10.      9.      0.  ]
#  [ -13.94   -4.22  -11.52  -15.37  -18.65  -16.45  -13.74  -10.45   -6.6
#     -0.89   -2.67   -0.33    0.     10.      9.      0.  ]
#  [ -13.94   -4.78  -13.21  -17.63  -20.93  -16.51  -14.38  -11.07   -6.66
#     -1.79   -5.35   -0.67    0.     10.      9.      0.  ]
#  [ -10.1    -3.07   -8.07  -11.97  -14.19  -11.11  -14.19  -11.97   -8.07
#     -2.7    -7.82   -1.02    0.     10.      9.      0.  ]
#  [ -19.09   -5.47  -14.3   -18.99  -22.57  -17.87  -15.2   -11.62   -6.93
#     -1.12    0.      0.      0.     10.      9.      0.  ]
#  [ -16.41   -5.14  -13.21  -17.63  -20.93  -16.51  -14.38  -11.07   -6.66
#     -4.67  -10.54   -3.55    0.     10.      9.      0.  ]
#  [   0.     -0.56   -3.6    -5.26   -6.37   -5.52   -6.37   -5.26   -3.6
#     -4.13  -10.34   -3.57    0.     10.      9.      0.  ]
#  [ -19.67   -7.5   -17.46  -24.82  -33.24  -27.52  -22.65  -15.85   -8.49
#     -1.23   -5.35   -0.67    0.     10.      9.      0.  ]
#  [ -13.94   -4.78  -13.48  -18.17  -21.75  -17.87  -16.01  -12.44   -7.75
#     -1.81   -5.15   -0.69    0.     10.      9.      0.  ]
#  [  -2.67   -2.24   -7.92  -12.55  -17.98  -14.98  -14.75  -10.67   -6.04
#     -3.44   -5.19   -2.88    0.     10.      9.      0.  ]
#  [  -2.67   -0.89   -3.33   -4.72   -5.55   -4.16   -4.73   -3.9    -2.51
#  [-124.39 -189.7  -151.9  -233.31 -308.7  -357.66 -346.26 -273.26 -205.16
#   -361.41 -321.48 -223.14    0.     12.     28.      3.  ]
#  [ -96.68 -134.65 -110.97 -158.48 -206.91 -236.92 -222.32 -177.22 -134.03
#   -389.73 -418.45 -301.46    0.     12.     28.      3.  ]
#  [ -85.6  -145.76 -149.77 -220.11 -295.44 -336.79 -312.97 -244.65 -178.66
#   -488.35 -504.18 -372.78    0.     12.     28.      3.  ]
#  [ -85.31 -154.8  -129.93 -196.68 -232.45 -267.17 -252.91 -229.12 -164.05
#   -390.97 -351.48 -261.49    0.     12.     28.      3.  ]
#  [-118.17 -131.23  -64.58  -90.52 -107.55 -107.64  -97.7   -79.07  -54.94
#   -108.94  -98.44  -65.91    0.     12.     28.      3.  ]
#  [-339.46 -370.2  -155.84 -228.56 -268.55 -296.65 -267.66 -222.98 -148.4
#   -420.72 -400.46 -306.74    0.     12.     28.      3.  ]
#  [-252.08 -284.93 -146.98 -211.28 -247.85 -273.51 -247.56 -202.89 -138.96
#   -454.49 -470.24 -358.32    0.     12.     28.      3.  ]
#  [-339.75 -347.64 -132.21 -190.24 -227.59 -249.89 -222.42 -185.31 -125.43
#   -389.01 -400.74 -299.51    0.     12.     28.      3.  ]
#  [-132.44 -169.39 -110.43 -161.34 -193.33 -215.97 -189.16 -160.9  -111.06
#   -213.07 -205.22 -130.67    0.     12.     28.      3.  ]]

# %%
X = data[:, :-1]

# %%
y = data[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %% [markdown]
# # Random Forest Classifier

# %%
rfc = RandomForestClassifier()
parameters = {'n_estimators':[80, 90, 100, 110, 120], 'max_features': (None, 'auto', 'log2'), 'random_state': [42], 'n_jobs': [-1], 'min_samples_leaf': [1, 2, 3, 4]}
clf = GridSearchCV(rfc, parameters)
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [80, 90, 100, 110, 120], 'max_features': (None, 'auto', 'log2'), 'random_state': [42], 'n_jobs': [-1], 'min_samples_leaf': [1, 2, 3, 4]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %% [markdown]
# # Model Evaluation Metrics

# %%
y_predrfc = clf.best_estimator_.predict(X_test)

# %%
print("RFC :", accuracy_score(y_test, y_predrfc))
# Out:
# ('RFC :', 0.8666666666666667)

# %%
confusion_matrix(y_test, y_predrfc)
# Out:
# array([[30,  0,  0,  1],
#        [ 2, 22,  3,  1],
#        [ 1,  0, 27,  1],
#        [ 3,  0,  4, 25]])

# %%
clf.best_estimator_.feature_importances_
# Out:
# array([ 0.18,  0.1 ,  0.07,  0.1 ,  0.11,  0.05,  0.07,  0.05,  0.06,
#         0.06,  0.09,  0.05,  0.  ,  0.01,  0.01])

# %%
clf.best_params_
# Out:
# {'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'n_estimators': 110,
#  'n_jobs': -1,
#  'random_state': 42}

# %% [markdown]
# # Transpile Model

# %%
from sklearn_porter import Porter

# %%
porter = Porter(clf.best_estimator_, language='js')
output = porter.export()
print(output)
# Out:
# var Brain = function(atts) {
#
#     var predict_000 = function(atts) {
#         var classes = new Array(4);
#
#         if (atts[7] <= -58.114341735839844) {
#             if (atts[11] <= -196.67904663085937) {
#                 if (atts[4] <= -252.12141418457031) {
#                     if (atts[9] <= -470.66082763671875) {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 2;
#                         classes[3] = 0;
#                     } else {
#                         if (atts[2] <= -187.76922607421875) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 1;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 1;
#                         }
#                     }
#                 } else {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 14;
#                 }
#             } else {
#                 if (atts[6] <= -79.777618408203125) {
#                     if (atts[1] <= -391.313720703125) {
#                         if (atts[7] <= -197.53874206542969) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 5;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 6;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         if (atts[8] <= -116.30618286132812) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 12;
#                             classes[3] = 0;
#                         } else {
#                             if (atts[10] <= -161.268310546875) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 6;
#                             } else {
#                                 if (atts[11] <= -56.500701904296875) {
#                                     classes[0] = 0;
#                                     classes[1] = 1;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 17;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         }
#                     }
#                 } else {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 6;
#                 }
#             }
#         } else {
#             if (atts[3] <= -41.068634033203125) {
#                 if (atts[8] <= -26.856468200683594) {
#                     if (atts[11] <= -45.494819641113281) {
#                         classes[0] = 0;
#                         classes[1] = 2;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     } else {
#                         if (atts[11] <= -22.836849212646484) {
#                             classes[0] = 1;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 1;
#                             classes[3] = 0;
#                         }
#                     }
#                 } else {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 5;
#                 }
#             } else {
#                 if (atts[8] <= -5.2112874984741211) {
#                     if (atts[7] <= -10.374279022216797) {
#                         if (atts[4] <= -21.615236282348633) {
#                             if (atts[5] <= -31.909191131591797) {
#                                 if (atts[9] <= -77.748565673828125) {
#                                     if (atts[2] <= -24.059282302856445) {
#                                         classes[0] = 1;
#                                         classes[1] = 0;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 5;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     }
#                                 } else {
#                                     classes[0] = 4;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 }
#                             } else {
#                                 if (atts[5] <= -21.392646789550781) {
#                                     classes[0] = 0;
#                                     classes[1] = 8;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 1;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         } else {
#                             classes[0] = 5;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 4;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 } else {
#                     if (atts[0] <= -217.48541259765625) {
#                         classes[0] = 0;
#                         classes[1] = 2;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     } else {
#                         if (atts[4] <= -15.112944602966309) {
#                             if (atts[11] <= -2.2688095569610596) {
#                                 classes[0] = 2;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 3;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             classes[0] = 5;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     }
#                 }
#             }
#         }
#         var i = 0, class_idx = 0, class_val = classes[0];
#         for (i = 1; i < 4; i++) {
#             if (classes[i] > class_val) {
#                 class_idx = i;
#                 class_val = classes[i];
#             }
#         }
#         return class_idx;
#     };
#     var predict_001 = function(atts) {
#         var classes = new Array(4);
#
#         if (atts[9] <= -9.8057861328125) {
#             if (atts[2] <= -19.511514663696289) {
#                 if (atts[10] <= -299.7283935546875) {
#                     if (atts[0] <= -364.65292358398437) {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 1;
#                         classes[3] = 0;
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 12;
#                     }
#                 } else {
#                     if (atts[5] <= -74.907516479492187) {
#                         if (atts[0] <= -347.80010986328125) {
#                             if (atts[8] <= -148.75839233398438) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 5;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 7;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             if (atts[5] <= -253.39950561523437) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 10;
#                                 classes[3] = 0;
#                             } else {
#                                 if (atts[10] <= -152.32373046875) {
#                                     if (atts[6] <= -189.95614624023437) {
#                                         if (atts[8] <= -114.1595458984375) {
#                                             classes[0] = 0;
#                                             classes[1] = 0;
#                                             classes[2] = 0;
#                                             classes[3] = 1;
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 0;
#                                             classes[2] = 1;
#                                             classes[3] = 0;
#                                         }
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 0;
#                                         classes[3] = 4;
#                                     }
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 14;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         }
#                     } else {
#                         if (atts[0] <= -91.002388000488281) {
#                             if (atts[5] <= -65.859382629394531) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 3;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 1;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             if (atts[0] <= -32.766822814941406) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 8;
#                             } else {
#                                 classes[0] = 1;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         }
#                     }
#                 }
#             } else {
#                 if (atts[7] <= -26.323747634887695) {
#                     classes[0] = 0;
#                     classes[1] = 1;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 } else {
#                     classes[0] = 10;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 }
#             }
#         } else {
#             if (atts[11] <= -3.0489463806152344) {
#                 classes[0] = 0;
#                 classes[1] = 11;
#                 classes[2] = 0;
#                 classes[3] = 0;
#             } else {
#                 if (atts[5] <= -10.491106033325195) {
#                     if (atts[0] <= -40.169097900390625) {
#                         if (atts[8] <= -25.656560897827148) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 1;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 5;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         classes[0] = 16;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 } else {
#                     classes[0] = 0;
#                     classes[1] = 8;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 }
#             }
#         }
#         var i = 0, class_idx = 0, class_val = classes[0];
#         for (i = 1; i < 4; i++) {
#             if (classes[i] > class_val) {
#                 class_idx = i;
#                 class_val = classes[i];
#             }
#         }
#         return class_idx;
#     };
#     var predict_002 = function(atts) {
#         var classes = new Array(4);
#
#         if (atts[3] <= -41.068634033203125) {
#             if (atts[11] <= -196.67904663085937) {
#                 if (atts[8] <= -292.8326416015625) {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 1;
#                     classes[3] = 0;
#                 } else {
#                     if (atts[4] <= -355.38897705078125) {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 1;
#                         classes[3] = 0;
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 19;
#                     }
#                 }
#             } else {
#                 if (atts[0] <= -103.93309020996094) {
#                     if (atts[8] <= -30.808620452880859) {
#                         if (atts[0] <= -348.89431762695312) {
#                             if (atts[6] <= -296.74749755859375) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 3;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 6;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             if (atts[5] <= -152.71209716796875) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 11;
#                                 classes[3] = 0;
#                             } else {
#                                 if (atts[5] <= -121.26249694824219) {
#                                     classes[0] = 0;
#                                     classes[1] = 1;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 4;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         }
#                     } else {
#                         classes[0] = 2;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 } else {
#                     if (atts[10] <= -54.796791076660156) {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 12;
#                     } else {
#                         if (atts[6] <= -86.865615844726563) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 3;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 2;
#                         }
#                     }
#                 }
#             }
#         } else {
#             if (atts[2] <= -6.9865636825561523) {
#                 if (atts[8] <= -25.545993804931641) {
#                     if (atts[9] <= -77.748565673828125) {
#                         classes[0] = 0;
#                         classes[1] = 2;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     } else {
#                         classes[0] = 1;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 } else {
#                     if (atts[8] <= -6.5152854919433594) {
#                         if (atts[6] <= -31.94428825378418) {
#                             if (atts[3] <= -27.675273895263672) {
#                                 classes[0] = 3;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 1;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             classes[0] = 25;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         if (atts[8] <= -6.2768573760986328) {
#                             classes[0] = 0;
#                             classes[1] = 3;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 3;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     }
#                 }
#             } else {
#                 if (atts[0] <= -147.82688903808594) {
#                     classes[0] = 0;
#                     classes[1] = 13;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 } else {
#                     if (atts[2] <= -5.1459598541259766) {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 2;
#                         classes[3] = 0;
#                     } else {
#                         classes[0] = 2;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 }
#             }
#         }
#         var i = 0, class_idx = 0, class_val = classes[0];
#         for (i = 1; i < 4; i++) {
#             if (classes[i] > class_val) {
#                 class_idx = i;
#                 class_val = classes[i];
#             }
#         }
#         return class_idx;
#     };
#     var predict_003 = function(atts) {
#         var classes = new Array(4);
#
#         if (atts[5] <= -52.349460601806641) {
#             if (atts[10] <= -299.7283935546875) {
#                 if (atts[5] <= -282.8826904296875) {
#                     if (atts[8] <= -150.79795837402344) {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 4;
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 3;
#                         classes[3] = 0;
#                     }
#                 } else {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 7;
#                 }
#             } else {
#                 if (atts[9] <= -214.63873291015625) {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 18;
#                     classes[3] = 0;
#                 } else {
#                     if (atts[0] <= -256.68951416015625) {
#                         classes[0] = 0;
#                         classes[1] = 10;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     } else {
#                         if (atts[7] <= -49.966041564941406) {
#                             if (atts[2] <= -78.205886840820312) {
#                                 if (atts[10] <= -173.03135681152344) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 2;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 2;
#                                     classes[3] = 0;
#                                 }
#                             } else {
#                                 if (atts[6] <= -143.59400939941406) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 6;
#                                     classes[3] = 0;
#                                 } else {
#                                     if (atts[10] <= -85.864692687988281) {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 0;
#                                         classes[3] = 3;
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 7;
#                                         classes[3] = 0;
#                                     }
#                                 }
#                             }
#                         } else {
#                             if (atts[11] <= -47.248359680175781) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 4;
#                             } else {
#                                 classes[0] = 1;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         }
#                     }
#                 }
#             }
#         } else {
#             if (atts[2] <= -6.817023754119873) {
#                 if (atts[6] <= -30.697578430175781) {
#                     classes[0] = 0;
#                     classes[1] = 7;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 } else {
#                     if (atts[0] <= -252.95440673828125) {
#                         classes[0] = 0;
#                         classes[1] = 2;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     } else {
#                         classes[0] = 24;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 }
#             } else {
#                 if (atts[13] <= 11.0) {
#                     if (atts[3] <= -4.6715002059936523) {
#                         if (atts[10] <= -9.0995683670043945) {
#                             classes[0] = 1;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 6;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 12;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 } else {
#                     classes[0] = 1;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 }
#             }
#         }
#         var i = 0, class_idx = 0, class_val = classes[0];
#         for (i = 1; i < 4; i++) {
#             if (classes[i] > class_val) {
#                 class_idx = i;
#                 class_val = classes[i];
#             }
#         }
#         return class_idx;
#     };
#     var predict_004 = function(atts) {
#         var classes = new Array(4);
#
#         if (atts[2] <= -24.987262725830078) {
#             if (atts[1] <= -40.788387298583984) {
#                 if (atts[8] <= -54.225131988525391) {
#                     if (atts[14] <= 18.5) {
#                         if (atts[9] <= -81.238533020019531) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 3;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 7;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         if (atts[1] <= -212.71611022949219) {
#                             if (atts[5] <= -218.04278564453125) {
#                                 if (atts[9] <= -405.552490234375) {
#                                     if (atts[5] <= -490.79837036132812) {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 1;
#                                         classes[3] = 0;
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 0;
#                                         classes[3] = 3;
#                                     }
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 6;
#                                     classes[3] = 0;
#                                 }
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 2;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             if (atts[2] <= -123.37381744384766) {
#                                 if (atts[7] <= -191.52922058105469) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 4;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 2;
#                                     classes[3] = 0;
#                                 }
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 13;
#                             }
#                         }
#                     }
#                 } else {
#                     if (atts[11] <= -24.306339263916016) {
#                         if (atts[6] <= -69.047515869140625) {
#                             classes[0] = 0;
#                             classes[1] = 3;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 1;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 6;
#                         classes[3] = 0;
#                     }
#                 }
#             } else {
#                 classes[0] = 0;
#                 classes[1] = 0;
#                 classes[2] = 0;
#                 classes[3] = 11;
#             }
#         } else {
#             if (atts[11] <= -23.236343383789063) {
#                 classes[0] = 16;
#                 classes[1] = 0;
#                 classes[2] = 0;
#                 classes[3] = 0;
#             } else {
#                 if (atts[7] <= -4.6797747611999512) {
#                     if (atts[6] <= -19.124044418334961) {
#                         if (atts[1] <= -61.615695953369141) {
#                             classes[0] = 0;
#                             classes[1] = 11;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 1;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         if (atts[1] <= -6.4190177917480469) {
#                             if (atts[1] <= -62.929058074951172) {
#                                 classes[0] = 0;
#                                 classes[1] = 4;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 2;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             classes[0] = 12;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     }
#                 } else {
#                     classes[0] = 0;
#                     classes[1] = 12;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 }
#             }
#         }
#         var i = 0, class_idx = 0, class_val = classes[0];
#         for (i = 1; i < 4; i++) {
#             if (classes[i] > class_val) {
#                 class_idx = i;
#                 class_val = classes[i];
#             }
#         }
#         return class_idx;
#     };
#     var predict_005 = function(atts) {
#         var classes = new Array(4);
#
#         if (atts[3] <= -45.294708251953125) {
#             if (atts[1] <= -32.34063720703125) {
#                 if (atts[9] <= -79.864776611328125) {
#                     if (atts[0] <= -226.86647033691406) {
#                         if (atts[5] <= -217.86288452148437) {
#                             if (atts[9] <= -446.6204833984375) {
#                                 if (atts[5] <= -334.3499755859375) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 1;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 2;
#                                     classes[3] = 0;
#                                 }
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 12;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 7;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         if (atts[3] <= -185.33041381835937) {
#                             if (atts[7] <= -204.40524291992187) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 2;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 2;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 12;
#                         }
#                     }
#                 } else {
#                     if (atts[10] <= -42.545051574707031) {
#                         if (atts[10] <= -80.962989807128906) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 5;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 1;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 13;
#                         classes[3] = 0;
#                     }
#                 }
#             } else {
#                 classes[0] = 0;
#                 classes[1] = 0;
#                 classes[2] = 0;
#                 classes[3] = 10;
#             }
#         } else {
#             if (atts[10] <= -87.183647155761719) {
#                 if (atts[2] <= -11.520278930664063) {
#                     classes[0] = 0;
#                     classes[1] = 7;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 } else {
#                     classes[0] = 1;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 }
#             } else {
#                 if (atts[1] <= -92.54193115234375) {
#                     if (atts[14] <= 18.5) {
#                         classes[0] = 0;
#                         classes[1] = 19;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     } else {
#                         if (atts[0] <= -444.63766479492187) {
#                             classes[0] = 0;
#                             classes[1] = 1;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 7;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     }
#                 } else {
#                     classes[0] = 18;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 }
#             }
#         }
#         var i = 0, class_idx = 0, class_val = classes[0];
#         for (i = 1; i < 4; i++) {
#             if (classes[i] > class_val) {
#                 class_idx = i;
#                 class_val = classes[i];
#             }
#         }
#         return class_idx;
#     };
#     var predict_006 = function(atts) {
#         var classes = new Array(4);
#
#         if (atts[7] <= -38.450973510742187) {
#             if (atts[10] <= -155.76119995117187) {
#                 if (atts[7] <= -151.52169799804687) {
#                     if (atts[2] <= -111.95028686523437) {
#                         if (atts[4] <= -244.82972717285156) {
#                             if (atts[8] <= -167.74777221679687) {
#                                 if (atts[2] <= -156.15115356445312) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 4;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 2;
#                                 }
#                             } else {
#                                 if (atts[9] <= -533.97100830078125) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 1;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 5;
#                                 }
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 4;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 3;
#                     }
#                 } else {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 12;
#                 }
#             } else {
#                 if (atts[0] <= -240.51779174804687) {
#                     if (atts[2] <= -152.3739013671875) {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 1;
#                         classes[3] = 0;
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 17;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 } else {
#                     if (atts[8] <= -26.847812652587891) {
#                         if (atts[0] <= -78.124404907226563) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 15;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 1;
#                         }
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 5;
#                     }
#                 }
#             }
#         } else {
#             if (atts[4] <= -15.817974090576172) {
#                 if (atts[4] <= -22.666271209716797) {
#                     if (atts[13] <= 11.0) {
#                         if (atts[0] <= -163.90121459960937) {
#                             classes[0] = 0;
#                             classes[1] = 6;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 1;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         if (atts[11] <= -111.29373931884766) {
#                             classes[0] = 0;
#                             classes[1] = 1;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 7;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     }
#                 } else {
#                     if (atts[8] <= -4.6131749153137207) {
#                         classes[0] = 18;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 1;
#                         classes[3] = 0;
#                     }
#                 }
#             } else {
#                 if (atts[14] <= 18.5) {
#                     if (atts[2] <= -3.2919282913208008) {
#                         if (atts[6] <= -9.9224109649658203) {
#                             classes[0] = 0;
#                             classes[1] = 3;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 1;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 11;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 } else {
#                     classes[0] = 1;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 }
#             }
#         }
#         var i = 0, class_idx = 0, class_val = classes[0];
#         for (i = 1; i < 4; i++) {
#             if (classes[i] > class_val) {
#                 class_idx = i;
#                 class_val = classes[i];
#             }
#         }
#         return class_idx;
#     };
#     var predict_007 = function(atts) {
#         var classes = new Array(4);
#
#         if (atts[0] <= -249.39961242675781) {
#             if (atts[3] <= -155.10476684570312) {
#                 if (atts[4] <= -333.55160522460937) {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 4;
#                     classes[3] = 0;
#                 } else {
#                     if (atts[4] <= -326.53485107421875) {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 1;
#                     } else {
#                         if (atts[9] <= -341.17236328125) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 1;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 4;
#                             classes[3] = 0;
#                         }
#                     }
#                 }
#             } else {
#                 classes[0] = 0;
#                 classes[1] = 33;
#                 classes[2] = 0;
#                 classes[3] = 0;
#             }
#         } else {
#             if (atts[8] <= -29.918708801269531) {
#                 if (atts[7] <= -248.78054809570312) {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 6;
#                     classes[3] = 0;
#                 } else {
#                     if (atts[10] <= -151.72488403320312) {
#                         if (atts[3] <= -171.99386596679687) {
#                             if (atts[7] <= -193.49725341796875) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 7;
#                             } else {
#                                 if (atts[5] <= -253.39950561523437) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 2;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 1;
#                                 }
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 15;
#                         }
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 11;
#                         classes[3] = 0;
#                     }
#                 }
#             } else {
#                 if (atts[10] <= -119.41129302978516) {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 0;
# ...
#                     classes[1] = 10;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 }
#             } else {
#                 if (atts[1] <= -40.788387298583984) {
#                     if (atts[9] <= -281.6436767578125) {
#                         if (atts[5] <= -399.16415405273437) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 3;
#                             classes[3] = 0;
#                         } else {
#                             if (atts[0] <= -387.80010986328125) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 1;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 13;
#                             }
#                         }
#                     } else {
#                         if (atts[4] <= -67.919631958007813) {
#                             if (atts[1] <= -218.2593994140625) {
#                                 if (atts[10] <= -96.809112548828125) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 8;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 3;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 }
#                             } else {
#                                 if (atts[1] <= -193.4527587890625) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 1;
#                                 } else {
#                                     if (atts[6] <= -146.99449157714844) {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 8;
#                                         classes[3] = 0;
#                                     } else {
#                                         if (atts[7] <= -87.782890319824219) {
#                                             if (atts[14] <= 18.5) {
#                                                 if (atts[6] <= -124.3428955078125) {
#                                                     classes[0] = 0;
#                                                     classes[1] = 0;
#                                                     classes[2] = 1;
#                                                     classes[3] = 0;
#                                                 } else {
#                                                     classes[0] = 0;
#                                                     classes[1] = 0;
#                                                     classes[2] = 0;
#                                                     classes[3] = 1;
#                                                 }
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 0;
#                                                 classes[2] = 0;
#                                                 classes[3] = 2;
#                                             }
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 0;
#                                             classes[2] = 3;
#                                             classes[3] = 0;
#                                         }
#                                     }
#                                 }
#                             }
#                         } else {
#                             classes[0] = 4;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     }
#                 } else {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 12;
#                 }
#             }
#         } else {
#             if (atts[1] <= -92.54193115234375) {
#                 if (atts[2] <= -21.363079071044922) {
#                     classes[0] = 1;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 } else {
#                     classes[0] = 0;
#                     classes[1] = 23;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 }
#             } else {
#                 if (atts[3] <= -12.018888473510742) {
#                     classes[0] = 19;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 } else {
#                     if (atts[11] <= -2.6127712726593018) {
#                         classes[0] = 2;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 1;
#                         classes[3] = 0;
#                     }
#                 }
#             }
#         }
#         var i = 0, class_idx = 0, class_val = classes[0];
#         for (i = 1; i < 4; i++) {
#             if (classes[i] > class_val) {
#                 class_idx = i;
#                 class_val = classes[i];
#             }
#         }
#         return class_idx;
#     };
#     var predict_109 = function(atts) {
#         var classes = new Array(4);
#
#         if (atts[3] <= -45.294708251953125) {
#             if (atts[0] <= -104.51703643798828) {
#                 if (atts[2] <= -159.30978393554687) {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 13;
#                     classes[3] = 0;
#                 } else {
#                     if (atts[7] <= -206.739501953125) {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 8;
#                     } else {
#                         if (atts[4] <= -214.22274780273437) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 9;
#                             classes[3] = 0;
#                         } else {
#                             if (atts[0] <= -283.84259033203125) {
#                                 classes[0] = 0;
#                                 classes[1] = 5;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 if (atts[10] <= -118.02417755126953) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 4;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 9;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         }
#                     }
#                 }
#             } else {
#                 if (atts[1] <= -34.261009216308594) {
#                     if (atts[13] <= 11.0) {
#                         if (atts[9] <= -87.011199951171875) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 2;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 4;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 7;
#                     }
#                 } else {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 10;
#                 }
#             }
#         } else {
#             if (atts[3] <= -13.425321578979492) {
#                 if (atts[10] <= -87.183647155761719) {
#                     if (atts[2] <= -24.059282302856445) {
#                         classes[0] = 1;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 3;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 } else {
#                     if (atts[0] <= -258.44668579101562) {
#                         classes[0] = 0;
#                         classes[1] = 2;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     } else {
#                         classes[0] = 27;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 }
#             } else {
#                 if (atts[11] <= -28.836776733398437) {
#                     classes[0] = 2;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 } else {
#                     if (atts[3] <= -10.751764297485352) {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 1;
#                         classes[3] = 0;
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 13;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 }
#             }
#         }
#         var i = 0, class_idx = 0, class_val = classes[0];
#         for (i = 1; i < 4; i++) {
#             if (classes[i] > class_val) {
#                 class_idx = i;
#                 class_val = classes[i];
#             }
#         }
#         return class_idx;
#     };
#
#     this.predict = function(atts) {
#         var i = 0, n_classes = 4;
#         var classes = new Array(n_classes);
#         for (i = 0; i < n_classes; i++) {
#             classes[i] = 0;
#         }
#
#         classes[predict_000(atts)]++;
#         classes[predict_001(atts)]++;
#         classes[predict_002(atts)]++;
#         classes[predict_003(atts)]++;
#         classes[predict_004(atts)]++;
#         classes[predict_005(atts)]++;
#         classes[predict_006(atts)]++;
#         classes[predict_007(atts)]++;
#         classes[predict_008(atts)]++;
#         classes[predict_009(atts)]++;
#         classes[predict_010(atts)]++;
#         classes[predict_011(atts)]++;
#         classes[predict_012(atts)]++;
#         classes[predict_013(atts)]++;
#         classes[predict_014(atts)]++;
#         classes[predict_015(atts)]++;
#         classes[predict_016(atts)]++;
#         classes[predict_017(atts)]++;
#         classes[predict_018(atts)]++;
#         classes[predict_019(atts)]++;
#         classes[predict_020(atts)]++;
#         classes[predict_021(atts)]++;
#         classes[predict_022(atts)]++;
#         classes[predict_023(atts)]++;
#         classes[predict_024(atts)]++;
#         classes[predict_025(atts)]++;
#         classes[predict_026(atts)]++;
#         classes[predict_027(atts)]++;
#         classes[predict_028(atts)]++;
#         classes[predict_029(atts)]++;
#         classes[predict_030(atts)]++;
#         classes[predict_031(atts)]++;
#         classes[predict_032(atts)]++;
#         classes[predict_033(atts)]++;
#         classes[predict_034(atts)]++;
#         classes[predict_035(atts)]++;
#         classes[predict_036(atts)]++;
#         classes[predict_037(atts)]++;
#         classes[predict_038(atts)]++;
#         classes[predict_039(atts)]++;
#         classes[predict_040(atts)]++;
#         classes[predict_041(atts)]++;
#         classes[predict_042(atts)]++;
#         classes[predict_043(atts)]++;
#         classes[predict_044(atts)]++;
#         classes[predict_045(atts)]++;
#         classes[predict_046(atts)]++;
#         classes[predict_047(atts)]++;
#         classes[predict_048(atts)]++;
#         classes[predict_049(atts)]++;
#         classes[predict_050(atts)]++;
#         classes[predict_051(atts)]++;
#         classes[predict_052(atts)]++;
#         classes[predict_053(atts)]++;
#         classes[predict_054(atts)]++;
#         classes[predict_055(atts)]++;
#         classes[predict_056(atts)]++;
#         classes[predict_057(atts)]++;
#         classes[predict_058(atts)]++;
#         classes[predict_059(atts)]++;
#         classes[predict_060(atts)]++;
#         classes[predict_061(atts)]++;
#         classes[predict_062(atts)]++;
#         classes[predict_063(atts)]++;
#         classes[predict_064(atts)]++;
#         classes[predict_065(atts)]++;
#         classes[predict_066(atts)]++;
#         classes[predict_067(atts)]++;
#         classes[predict_068(atts)]++;
#         classes[predict_069(atts)]++;
#         classes[predict_070(atts)]++;
#         classes[predict_071(atts)]++;
#         classes[predict_072(atts)]++;
#         classes[predict_073(atts)]++;
#         classes[predict_074(atts)]++;
#         classes[predict_075(atts)]++;
#         classes[predict_076(atts)]++;
#         classes[predict_077(atts)]++;
#         classes[predict_078(atts)]++;
#         classes[predict_079(atts)]++;
#         classes[predict_080(atts)]++;
#         classes[predict_081(atts)]++;
#         classes[predict_082(atts)]++;
#         classes[predict_083(atts)]++;
#         classes[predict_084(atts)]++;
#         classes[predict_085(atts)]++;
#         classes[predict_086(atts)]++;
#         classes[predict_087(atts)]++;
#         classes[predict_088(atts)]++;
#         classes[predict_089(atts)]++;
#         classes[predict_090(atts)]++;
#         classes[predict_091(atts)]++;
#         classes[predict_092(atts)]++;
#         classes[predict_093(atts)]++;
#         classes[predict_094(atts)]++;
#         classes[predict_095(atts)]++;
#         classes[predict_096(atts)]++;
#         classes[predict_097(atts)]++;
#         classes[predict_098(atts)]++;
#         classes[predict_099(atts)]++;
#         classes[predict_100(atts)]++;
#         classes[predict_101(atts)]++;
#         classes[predict_102(atts)]++;
#         classes[predict_103(atts)]++;
#         classes[predict_104(atts)]++;
#         classes[predict_105(atts)]++;
#         classes[predict_106(atts)]++;
#         classes[predict_107(atts)]++;
#         classes[predict_108(atts)]++;
#         classes[predict_109(atts)]++;
#
#         var class_idx = 0, class_val = classes[0];
#         for (i = 1; i < n_classes; i++) {
#             if (classes[i] > class_val) {
#                 class_idx = i;
#                 class_val = classes[i];
#             }
#         }
#         return class_idx;
#     }
#
# };
#
# if (typeof process !== 'undefined' && typeof process.argv !== 'undefined') {
#     if (process.argv.length - 2 == 15) {
#         var argv = process.argv.slice(2);
#         var prediction = new Brain().predict(argv);
#         console.log(prediction);
#     }
# }
